# %%
#Importing data preprocessing libraries 
import pandas as pd
import numpy as np

#Turning off warning messages
import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

#Importing visualization libraries 
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

#Importing machine learning libs 
from sklearn.model_selection import train_test_split


from sklearn.metrics import confusion_matrix,classification_report,plot_confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegressionCV 
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import r2_score
from sklearn.metrics import f1_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error
from sklearn.metrics import plot_precision_recall_curve,plot_roc_curve
from sklearn.metrics import classification_report

# %%
from sklearn.svm import SVR,LinearSVR

# %%
df = pd.read_csv('TOWN.csv')

# %%
df
# Out:
#         Time       Date  Latitude  Longitude  Total PDCP DL Throughput  \
# 0    45:03.0  3/21/2022  7.284432   5.182462                      2.20
# 1    45:05.0  3/21/2022  7.284394   5.182783                      1.44
# 2    45:07.0  3/21/2022  7.284349   5.183107                      2.57
# 3    45:09.0  3/21/2022  7.284296   5.183431                      0.39
# 4    45:11.0  3/21/2022  7.284237   5.183754                      0.93
# ..       ...        ...       ...        ...                       ...
# 258  53:51.0  3/21/2022  7.277382   5.229066                      0.78
# 259  53:53.0  3/21/2022  7.277303   5.229324                      0.39
# 260  53:55.0  3/21/2022  7.277232   5.229578                      0.78
# 261  53:57.0  3/21/2022  7.277165   5.229830                      0.78
# 262  53:59.0  3/21/2022  7.277099   5.230078                      1.46
#
#      Total PDCP UL Throughput  PDSCH Phy Throughput (kbps)  \
# 0                        3.20                         3.04
# 1                        1.50                         1.34
# 2                        2.97                         5.27
# 3                        2.26                         1.62
# 4                        2.45                         5.96
# ..                        ...                          ...
# 258                      1.68                         2.80
# 259                      1.32                         2.50
# 260                      1.04                         2.55
# 261                      0.52                         2.50
# 262                      2.93                         2.72
#
#      PUSCH Phy Throughput (kbps)  \
# 0                      77.699997
# 1                      83.849998
# 2                      99.989998
# 3                      90.410004
# 4                     130.570007
# ..                           ...
# 258                   118.870003
# 259                   114.449997
# 260                   119.980003
# 261                   120.239998
# 262                   121.980003
#
#      PDSCH Resource Blocks Allocated (Allocated Subframes Only)  \
# 0                                                  7.8
# 1                                                  6.6
# 2                                                  7.6
# 3                                                  5.5
# 4                                                  3.9
# ..                                                 ...
# 258                                                4.0
# 259                                                3.8
# 260                                                4.6
# 261                                                3.8
# 262                                                4.2
#
#      PDSCH Resource Block Allocation (%)  \
# 0                                   0.11
# 1                                   0.02
# 2                                   0.03
# 3                                   0.19
# 4                                   0.17
# ..                                   ...
# 258                                 0.13
# 259                                 0.68
# 260                                 0.10
# 261                                 0.08
# 262                                 0.10
#
#      PUSCH Resource Blocks Allocated (Allocated Subframes Only)  \
# 0                                                  4.3
# 1                                                  2.3
# 2                                                  2.7
# 3                                                  2.4
# 4                                                  3.9
# ..                                                 ...
# 258                                                2.2
# 259                                                2.2
# 260                                                2.2
# 261                                                2.2
# 262                                                2.2
#
#      Number of PUSCH Resource Blocks  Number of PDSCH Resource Blocks  \
# 0                                0.2                              0.1
# 1                                0.7                              0.0
# 2                                0.2                              0.0
# 3                                0.2                              0.2
# 4                                0.2                              0.2
# ..                               ...                              ...
# 258                              0.3                              0.1
# 259                              0.3                              0.7
# 260                              0.3                              0.1
# 261                              0.3                              0.1
# 262                              0.3                              0.1
#
#      PDCP Throughput DL (kbps)  PDCP Throughput UL (kbps)  \
# 0                         2.29                       5.37
# 1                         1.29                       1.51
# 2                         2.35                       2.00
# 3                         0.52                       2.26
# 4                         0.95                       1.85
# ..                         ...                        ...
# 258                       0.78                       1.68
# 259                       0.52                       1.32
# 260                       0.78                       1.04
# 261                       0.78                       0.69
# 262                       1.46                       2.78
#
#      PHY Layer Throughput PDSCH (kbps)  PHY Layer Throughput PUSCH (kbps)  \
# 0                                 5.54                          91.309998
# 1                                 4.32                         112.809998
# 2                                 9.23                         123.360001
# 3                                 4.69                         115.150002
# 4                                 5.41                         129.000000
# ..                                 ...                                ...
# 258                               2.59                         124.230003
# 259                               3.39                         118.870003
# 260                               1.40                         125.760002
# 261                               3.69                         125.389999
# 262                               6.14                         126.589996
#
#      RLC Throughput DL (kbps)(LTE Throughputs from Data Collector)  \
# 0                                                 2.00
# 1                                                 1.15
# 2                                                 1.65
# 3                                                 1.68
# 4                                                 0.90
# ..                                                 ...
# 258                                               1.00
# 259                                               0.67
# 260                                               0.65
# 261                                               1.30
# 262                                               1.23
#
#      RLC Throughput UL (kbps)(LTE Throughputs from Data Collector)
# 0                                                 4.88
# 1                                                 1.04
# 2                                                 3.99
# 3                                                 2.22
# 4                                                 2.08
# ..                                                 ...
# 258                                               2.13
# 259                                               1.15
# 260                                               1.50
# 261                                               0.77
# 262                                               3.04
#
# [263 rows x 19 columns]

# %%
df.drop('Date', axis =1, inplace = True)

# %%
df.drop('Time', axis =1, inplace = True)

# %%
df
# Out:
#      Latitude  Longitude  Total PDCP DL Throughput  Total PDCP UL Throughput  \
# 0    7.284432   5.182462                      2.20                      3.20
# 1    7.284394   5.182783                      1.44                      1.50
# 2    7.284349   5.183107                      2.57                      2.97
# 3    7.284296   5.183431                      0.39                      2.26
# 4    7.284237   5.183754                      0.93                      2.45
# ..        ...        ...                       ...                       ...
# 258  7.277382   5.229066                      0.78                      1.68
# 259  7.277303   5.229324                      0.39                      1.32
# 260  7.277232   5.229578                      0.78                      1.04
# 261  7.277165   5.229830                      0.78                      0.52
# 262  7.277099   5.230078                      1.46                      2.93
#
#      PDSCH Phy Throughput (kbps)  PUSCH Phy Throughput (kbps)  \
# 0                           3.04                    77.699997
# 1                           1.34                    83.849998
# 2                           5.27                    99.989998
# 3                           1.62                    90.410004
# 4                           5.96                   130.570007
# ..                           ...                          ...
# 258                         2.80                   118.870003
# 259                         2.50                   114.449997
# 260                         2.55                   119.980003
# 261                         2.50                   120.239998
# 262                         2.72                   121.980003
#
#      PDSCH Resource Blocks Allocated (Allocated Subframes Only)  \
# 0                                                  7.8
# 1                                                  6.6
# 2                                                  7.6
# 3                                                  5.5
# 4                                                  3.9
# ..                                                 ...
# 258                                                4.0
# 259                                                3.8
# 260                                                4.6
# 261                                                3.8
# 262                                                4.2
#
#      PDSCH Resource Block Allocation (%)  \
# 0                                   0.11
# 1                                   0.02
# 2                                   0.03
# 3                                   0.19
# 4                                   0.17
# ..                                   ...
# 258                                 0.13
# 259                                 0.68
# 260                                 0.10
# 261                                 0.08
# 262                                 0.10
#
#      PUSCH Resource Blocks Allocated (Allocated Subframes Only)  \
# 0                                                  4.3
# 1                                                  2.3
# 2                                                  2.7
# 3                                                  2.4
# 4                                                  3.9
# ..                                                 ...
# 258                                                2.2
# 259                                                2.2
# 260                                                2.2
# 261                                                2.2
# 262                                                2.2
#
#      Number of PUSCH Resource Blocks  Number of PDSCH Resource Blocks  \
# 0                                0.2                              0.1
# 1                                0.7                              0.0
# 2                                0.2                              0.0
# 3                                0.2                              0.2
# 4                                0.2                              0.2
# ..                               ...                              ...
# 258                              0.3                              0.1
# 259                              0.3                              0.7
# 260                              0.3                              0.1
# 261                              0.3                              0.1
# 262                              0.3                              0.1
#
#      PDCP Throughput DL (kbps)  PDCP Throughput UL (kbps)  \
# 0                         2.29                       5.37
# 1                         1.29                       1.51
# 2                         2.35                       2.00
# 3                         0.52                       2.26
# 4                         0.95                       1.85
# ..                         ...                        ...
# 258                       0.78                       1.68
# 259                       0.52                       1.32
# 260                       0.78                       1.04
# 261                       0.78                       0.69
# 262                       1.46                       2.78
#
#      PHY Layer Throughput PDSCH (kbps)  PHY Layer Throughput PUSCH (kbps)  \
# 0                                 5.54                          91.309998
# 1                                 4.32                         112.809998
# 2                                 9.23                         123.360001
# 3                                 4.69                         115.150002
# 4                                 5.41                         129.000000
# ..                                 ...                                ...
# 258                               2.59                         124.230003
# 259                               3.39                         118.870003
# 260                               1.40                         125.760002
# 261                               3.69                         125.389999
# 262                               6.14                         126.589996
#
#      RLC Throughput DL (kbps)(LTE Throughputs from Data Collector)  \
# 0                                                 2.00
# 1                                                 1.15
# 2                                                 1.65
# 3                                                 1.68
# 4                                                 0.90
# ..                                                 ...
# 258                                               1.00
# 259                                               0.67
# 260                                               0.65
# 261                                               1.30
# 262                                               1.23
#
#      RLC Throughput UL (kbps)(LTE Throughputs from Data Collector)
# 0                                                 4.88
# 1                                                 1.04
# 2                                                 3.99
# 3                                                 2.22
# 4                                                 2.08
# ..                                                 ...
# 258                                               2.13
# 259                                               1.15
# 260                                               1.50
# 261                                               0.77
# 262                                               3.04
#
# [263 rows x 17 columns]

# %%
df.drop("Total PDCP DL Throughput", axis=1, inplace=True)

# %%
X = df.drop('Total PDCP UL Throughput',axis=1)
y = df['Total PDCP UL Throughput']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
param_grid = {'C':[0.001,0.01,0.1,0.5,1],
              'gamma':['scale','auto'],}

# %%
from sklearn.model_selection import GridSearchCV

# %%
svr = SVR()
grid = GridSearchCV(svr,param_grid=param_grid)

# %%
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.001, 0.01, 0.1, 0.5, 1],
#                          'gamma': ['scale', 'auto']})

# %%
grid.best_params_
# Out:
# {'C': 1, 'gamma': 'auto'}
